# %%
import json
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
blob_service_client = BlobServiceClient.from_connection_string('DefaultEndpointsProtocol=https;AccountName=checklistform;AccountKey=dpZeiTIELCgVGxRxqYkhqAx42b8pWND2onchJ83+yXgHqbkMkPS5aKbmmVMtdDJdENFmmH3EuHhANmUQ02d7TQ==;EndpointSuffix=core.windows.net')
container_client = blob_service_client.get_container_client("analysedlicense")

# %%
# result1{'status': 'succeeded', 'createdDateTime': '2020-08-19T05:11:34Z', 'lastUpdatedDateTime': '2020-08-19T05:11:53Z', 'analyzeResult': {'version': '2.0.0', 'readResults': [{'page': 1, 'language': 'en', 'angle': 0, 'width': 8.5, 'height': 11, 'unit': 'inch', 'lines': [{'boundingBox': [1.0109, 1.0952, 1.4542, 1.0952, 1.4542, 1.2073, 1.0109, 1.2073], 'text': 'Name:', 'words': [{'boundingBox': [1.0109, 1.0952, 1.4542, 1.0952, 1.4542, 1.2073, 1.0109, 1.2073], 'text': 'Name:', 'confidence': 1}]}, {'boundingBox': [1.8154, 1.0923, 2.4672, 1.0923, 2.4672, 1.208, 1.8154, 1.208], 'text': 'Chandler', 'words': [{'boundingBox': [1.8154, 1.0923, 2.4672, 1.0923, 2.4672, 1.208, 1.8154, 1.208], 'text': 'Chandler', 'confidence': 1}]}, {'boundingBox': [4.691, 1.0923, 5.8597, 1.0923, 5.8597, 1.2379, 4.691, 1.2379], 'text': 'Employee Code:', 'words': [{'boundingBox': [4.691, 1.0952, 5.3937, 1.0952, 5.3937, 1.2379, 4.691, 1.2379], 'text': 'Employee', 'confidence': 1}, {'boundingBox': [5.4475, 1.0923, 5.8597, 1.0923, 5.8597, 1.208, 5.4475, 1.208], 'text': 'Code:', 'confidence': 1}]}, {'boundingBox': [5.91, 1.04, 6.69, 1.0167, 6.6933, 1.17, 5.91, 1.1867], 'text': '10701', 'words': [{'boundingBox': [5.925, 1.0456, 6.6739, 1.0181, 6.67, 1.1729, 5.9152, 1.1861], 'text': '10701', 'confidence': 0.446}]}, {'boundingBox': [1.0071, 1.3323, 1.7323, 1.3323, 1.7323, 1.4779, 1.0071, 1.4779], 'text': 'Company:', 'words': [{'boundingBox': [1.0071, 1.3323, 1.7323, 1.3323, 1.7323, 1.4779, 1.0071, 1.4779], 'text': 'Company:', 'confidence': 1}]}, {'boundingBox': [1.8233, 1.2733, 3.0367, 1.25, 3.04, 1.4067, 1.8233, 1.42], 'text': 'secret service', 'words': [{'boundingBox': [1.8368, 1.2867, 2.4588, 1.2687, 2.4602, 1.415, 1.8396, 1.4189], 'text': 'secret', 'confidence': 0.799}, {'boundingBox': [2.5192, 1.267, 3.0332, 1.2534, 3.0335, 1.411, 2.5205, 1.4146], 'text': 'service', 'confidence': 0.478}]}, {'boundingBox': [1.0037, 1.6839, 1.9338, 1.6839, 1.9338, 1.7997, 1.0037, 1.7997], 'text': 'JOB DESIGN', 'words': [{'boundingBox': [1.0037, 1.6869, 1.3075, 1.6869, 1.3075, 1.7997, 1.0037, 1.7997], 'text': 'JOB', 'confidence': 1}, {'boundingBox':
String': 'Is handling performed below mid-thigh height or above shoulder height?', 'text': 'Is handling performed below mid-thigh height or above shoulder height?', 'page': 1, 'boundingBox': [1.015, 6.165, 5.85, 6.165, 5.85, 6.31, 1.015, 6.31], 'confidence': 0.711, 'elements': ['#/readResults/0/lines/35/words/0', '#/readResults/0/lines/35/words/1', '#/readResults/0/lines/35/words/2', '#/readResults/0/lines/35/words/3', '#/readResults/0/lines/35/words/4', '#/readResults/0/lines/35/words/5', '#/readResults/0/lines/35/words/6', '#/readResults/0/lines/35/words/7', '#/readResults/0/lines/35/words/8', '#/readResults/0/lines/35/words/9']}, 'question10': {'type': 'string', 'valueString': 'Is handling required more than 5 times per hour over a day?', 'text': 'Is handling required more than 5 times per hour over a day?', 'page': 1, 'boundingBox': [1.015, 5.805, 5.05, 5.805, 5.05, 5.95, 1.015, 5.95], 'confidence': 0.64, 'elements': ['#/readResults/0/lines/33/words/0', '#/readResults/0/lines/33/words/1', '#/readResults/0/lines/33/words/2', '#/readResults/0/lines/33/words/3', '#/readResults/0/lines/33/words/4', '#/readResults/0/lines/33/words/5', '#/readResults/0/lines/33/words/6', '#/readResults/0/lines/33/words/7', '#/readResults/0/lines/33/words/8', '#/readResults/0/lines/33/words/9', '#/readResults/0/lines/33/words/10', '#/readResults/0/lines/33/words/11']}, 'question3': {'type': 'string', 'valueString': 'Do tasks require constant sitting or standing for more than 2 hours at any one time?', 'text': 'Do tasks require constant sitting or standing for more than 2 hours at any one time?', 'page': 1, 'boundingBox': [1.015, 2.585, 6.64, 2.585, 6.64, 2.73, 1.015, 2.73], 'confidence': 0.479, 'elements': ['#/readResults/0/lines/13/words/0', '#/readResults/0/lines/13/words/1', '#/readResults/0/lines/13/words/2', '#/readResults/0/lines/13/words/3', '#/readResults/0/lines/13/words/4', '#/readResults/0/lines/13/words/5', '#/readResults/0/lines/13/words/6', '#/readResults/0/lines/13/words/7', '#/readResults/0/lines/13/words/8', '#/readResults/0/lines/13/words/9', '#/readResults/0/lines/13/words/10', '#/readResults/0/lines/13/words/11', '#/readResults/0/lines/13/words/12', '#/readResults/0/lines/13/words/13', '#/readResults/0/lines/13/words/14', '#/readResults/0/lines/13/words/15']}, 'answer2': {'type': 'string', 'valueString': 'X', 'text': 'X', 'page': 1, 'boundingBox': [6.885, 2.225, 7.03, 2.225, 7.03, 2.435, 6.885, 2.435], 'confidence': 0.969, 'elements': ['#/readResults/0/lines/11/words/0']}, 'Name': {'type': 'string', 'valueString': 'Chandler', 'text': 'Chandler', 'page': 1, 'boundingBox': [1.815, 1.09, 2.465, 1.09, 2.465, 1.21, 1.815, 1.21], 'confidence': 0.656, 'elements': ['#/readResults/0/lines/1/words/0']}, 'answer16': {'type': 'string', 'valueString': 'X', 'text': 'X', 'page': 1, 'boundingBox': [6.88, 9.015, 7.02, 9.015, 7.02, 9.23, 6.88, 9.23], 'confidence': 0.277, 'elements': ['#/readResults/0/lines/51/words/0']}, 'question19': {'type': 'string', 'valueString': 'Do screens or partitions control noise?', 'text': 'Do screens or partitions control noise?', 'page': 1, 'boundingBox': [1.015, 9.715, 3.6, 9.715, 3.6, 9.855, 1.015, 9.855], 'confidence': 0.874, 'elements': ['#/readResults/0/lines/54/words/0', '#/readResults/0/lines/54/words/1', '#/readResults/0/lines/54/words/2', '#/readResults/0/lines/54/words/3', '#/readResults/0/lines/54/words/4', '#/readResults/0/lines/54/words/5']}, 'answer10': {'type': 'string', 'valueString': 'X', 'text': 'X', 'page': 1, 'boundingBox': [6.88, 5.82, 7.02, 5.82, 7.02, 6.03, 6.88, 6.03], 'confidence': 0.57, 'elements': ['#/readResults/0/lines/34/words/0']}, 'question6': {'type': 'string', 'valueString': 'Are workers trained to vary tasks and postures through the day?', 'text': 'Are workers trained to vary tasks and postures through the day?', 'page': 1, 'boundingBox': [1.0, 3.84, 5.33, 3.84, 5.33, 3.985, 1.0, 3.985], 'confidence': 1.0, 'elements': ['#/readResults/0/lines/22/words/0', '#/readResults/0/lines/22/words/1', '#/readResults/0/lines/22/words/2', '#/readResults/0/lines/22/words/3', '#/readResults/0/lines/22/words/4', '#/readResults/0/lines/22/words/5', '#/readResults/0/lines/22/words/6', '#/readResults/0/lines/22/words/7', '#/readResults/0/lines/22/words/8', '#/readResults/0/lines/22/words/9', '#/readResults/0/lines/22/words/10']}, 'answer4': {'type': 'string', 'valueString': 'X', 'text': 'X', 'page': 1, 'boundingBox': [6.88, 3.325, 7.015, 3.325, 7.015, 3.525, 6.88, 3.525], 'confidence': 0.66, 'elements': ['#/readResults/0/lines/19/words/0']}, 'answer13': {'type': 'string', 'valueString': 'X', 'text': 'X', 'page': 1, 'boundingBox': [6.875, 7.62, 7.02, 7.62, 7.02, 7.835, 6.875, 7.835], 'confidence': 0.705, 'elements': ['#/readResults/0/lines/44/words/0']}, 'question4': {'type': 'string', 'valueString': 'Are tasks that require a high level of concentration performed for more than 2 hours at any one time?', 'text': 'Are tasks that require a high level of concentration performed for more than 2 hours at any one time?', 'page': 1, 'boundingBox': [1.0, 2.945, 6.635, 2.945, 6.635, 3.265, 1.0, 3.265], 'confidence': 0.969, 'elements': ['#/readResults/0/lines/15/words/0', '#/readResults/0/lines/15/words/1', '#/readResults/0/lines/15/words/2', '#/readResults/0/lines/15/words/3', '#/readResults/0/lines/15/words/4', '#/readResults/0/lines/15/words/5', '#/readResults/0/lines/15/words/6', '#/readResults/0/lines/15/words/7', '#/readResults/0/lines/15/words/8', '#/readResults/0/lines/15/words/9', '#/readResults/0/lines/15/words/10', '#/readResults/0/lines/15/words/11', '#/readResults/0/lines/15/words/12', '#/readResults/0/lines/15/words/13', '#/readResults/0/lines/15/words/14', '#/readResults/0/lines/16/words/0', '#/readResults/0/lines/16/words/1', '#/readResults/0/lines/16/words/2', '#/readResults/0/lines/16/words/3']}, 'question16': {'type': 'string', 'valueString': 'Is noise a problem in the workplace?', 'text': 'Is noise a problem in the workplace?', 'page': 1, 'boundingBox': [1.015, 8.67, 3.47, 8.67, 3.47, 8.815, 1.015, 8.815], 'confidence': 0.696, 'elements': ['
', '#/readResults/0/lines/42/words/6', '#/readResults/0/lines/42/words/7', '#/readResults/0/lines/42/words/8', '#/readResults/0/lines/42/words/9', '#/readResults/0/lines/42/words/10', '#/readResults/0/lines/42/words/11', '#/readResults/0/lines/43/words/0']}, 'question18': {'type': 'string', 'valueString': 'Are there distracting or disruptive noises in the area?', 'text': 'Are there distracting or disruptive noises in the area?', 'page': 1, 'boundingBox': [1.0, 9.355, 4.565, 9.355, 4.565, 9.5, 1.0, 9.5], 'confidence': 0.969, 'elements': ['#/readResults/0/lines/52/words/0', '#/readResults/0/lines/52/words/1', '#/readResults/0/lines/52/words/2', '#/readResults/0/lines/52/words/3', '#/readResults/0/lines/52/words/4', '#/readResults/0/lines/52/words/5', '#/readResults/0/lines/52/words/6', '#/readResults/0/lines/52/words/7', '#/readResults/0/lines/52/words/8']}, 'answer15': {'type': 'string', 'valueString': 'X', 'text': 'X', 'page': 1, 'boundingBox': [6.88, 8.705, 7.02, 8.705, 7.02, 8.915, 6.88, 8.915], 'confidence': 0.706, 'elements': ['#/readResults/0/lines/49/words/0']}, 'answer6': {'type': 'string', 'valueString': 'X', 'text': 'X', 'page': 1, 'boundingBox': [6.88, 3.875, 7.015, 3.875, 7.015, 4.075, 6.88, 4.075], 'confidence': 0.638, 'elements': ['#/readResults/0/lines/23/words/0']}, 'answer12': {'type': 'string', 'valueString': 'X', 'text': 'X', 'page': 1, 'boundingBox': [6.875, 7.265, 7.005, 7.265, 7.005, 7.465, 6.875, 7.465], 'confidence': 0.748, 'elements': ['#/readResults/0/lines/41/words/0']}, 'answer1': {'type': 'string', 'valueString': 'X', 'text': 'X', 'page': 1, 'boundingBox': [6.875, 1.925, 7.015, 1.925, 7.015, 2.135, 6.875, 2.135], 'confidence': 0.911, 'elements': ['#/readResults/0/lines/9/words/0']}, 'Employee Code': {'type': 'string', 'valueString': '10701', 'text': '10701', 'page': 1, 'boundingBox': [5.915, 1.02, 6.675, 1.02, 6.675, 1.185, 5.915, 1.185], 'confidence': 0.979, 'elements': ['#/readResults/0/lines/3/words/0']}, 'question7': {'type': 'string', 'valueString': 'Are individuals given feedback regarding their work performance?', 'text': 'Are individuals given feedback regarding their work performance?', 'page': 1, 'boundingBox': [1.0, 4.195, 5.43, 4.195, 5.43, 4.34, 1.0, 4.34], 'confidence': 0.785, 'elements': ['#/readResults/0/lines/24/words/0', '#/readResults/0/lines/24/words/1', '#/readResults/0/lines/24/words/2', '#/readResults/0/lines/24/words/3', '#/readResults/0/lines/24/words/4', '#/readResults/0/lines/24/words/5', '#/readResults/0/lines/24/words/6', '#/readResults/0/lines/24/words/7']}, 'answer18': None, 'answer5': None, 'answer7': None, 'answer8': None}}], 'errors': []}}

# %%
 313, 388, 333, 274, 333], "confidence": 0.515, "elements": ["#/readResults/0/lines/14/words/1"]}, "DOB": {"type": "string", "valueString": "08/31/1978", "text": "08/31/1978", "page": 1, "boundingBox": [259, 287, 372, 287, 372, 305, 259, 305], "confidence": 0.55, "elements": ["#/readResults/0/lines/13/words/1"]}, "Address": {"type": "string", "valueString": "2345 ANYWHERE STREET YOUR CITY, NY 12345", "text": "2345 ANYWHERE STREET YOUR CITY, NY 12345", "page": 1, "boundingBox": [228, 183, 443, 183, 443, 218, 228, 218], "confidence": 0.591, "elements": ["#/readResults/0/lines/10/words/0", "#/readResults/0/lines/10/words/1", "#/readResults/0/lines/10/words/2", "#/readResults/0/lines/11/words/0", "#/readResults/0/lines/11/words/1", "#/readResults/0/lines/11/words/2", "#/readResults/0/lines/11/words/3"]}, "Name": {"type": "string", "valueString": "MOTORIST MICHAEL, M", "text": "MOTORIST MICHAEL, M", "page": 1, "boundingBox": [228, 135, 345, 135, 345, 176, 228, 176], "confidence": 0.467, "elements": ["#/readResults/0/lines/7/words/0", "#/readResults/0/lines/8/words/0", "#/readResults/0/lines/8/words/1"]}}}], "errors": []}}

# %%
analysed_Json = []
blob_list = container_client.list_blobs()
for blob in blob_list:
    analysed_Json.append(blob.name)
fields = result['analyzeResult']['documentResults'][0]['fields']
IsQA=False

allkeys = list(fields.keys())
temp=[x for x in fields if not x.startswith('question')]
k=[x for x in temp if not x.startswith('answer')]
label = []
value = []
for i in k:
    val=result['analyzeResult']['documentResults'][0]['fields'][i]   
    if val!=None:
        label.append(i)
        value.append(val['text'])
    
queList=[x for x in allkeys if  x.startswith('question')]
ansList=[x for x in allkeys if  x.startswith('answer')]

for i in range(1, len([x for x in fields if x.startswith('question')]), 1):
    if 'question' + str(i) in fields:
        IsQA=True
    # if i != 14:
        Name = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]
        Name = get_key(fields,Name)
        NameValue = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]['text']
        label.append(Name)
        value.append(NameValue)

for i in range(1, len([x for x in fields if x.startswith('answer')]), 1):
    Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]
    for i in range(1, 19, 1):
        Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]
        if Name != None:
            Name = get_key(fields,Name)
            NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]['text']
            label.append(Name)
            value.append(NameValue)
        else:
                result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)] = {'type': 'string',
                                                                                              'valueString': 'Y',
                                                                                              'text': 'Y',
                                                                                              'page': 1,
                                                                                              'boundingBox': [],
                                                                                              'confidence': 0,
                                                                                              'elements': []}

                NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]['text']
        label.append('answer' + str(i))
        value.append(NameValue)

finalData = dict(zip(label, value))
finalData
GridList={}
data2 = []
for i in k:
    data2.append({'Label': ""+str(i), 'Values': finalData[i]})

for d in range(1, len(queList), 1):
    if 'question' + str(d) in finalData :
        
        # if d != 14:
        data2.append({'Label':finalData['question' + str(d)],'Values': finalData['answer' + str(d)]})
GridList['IsQA'] = IsQA
GridList["FileName"] = analysed_Json
GridList['GridData'] = data2
GridList
# Out:
# {'IsQA': False,
#  'FileName': ['Result-License.json',
#   'Result-License12.json',
#   'Result-License14.json',
#   'Result-License2.json',
#   'Result-License4.json',
#   'Result-License5.json',
#   'Result-License9.json'],
#  'GridData': [{'Label': 'State', 'Values': 'NEW YORK STAT'},
#   {'Label': 'ID', 'Values': 'ID 123 456 789'},
#   {'Label': 'Issued', 'Values': '08/31/2013'},
#   {'Label': 'Type', 'Values': 'DRIVER LICENSE'},
#   {'Label': 'Expires', 'Values': '08/31/2021'},
#   {'Label': 'DOB', 'Values': '08/31/1978'},
#   {'Label': 'Address', 'Values': '2345 ANYWHERE STREET YOUR CITY, NY 12345'},
#   {'Label': 'Name', 'Values': 'MOTORIST MICHAEL, M'}]}

# %%
print(queList)
# Out:
# ['question8', 'question5', 'question1', 'question11', 'question10', 'question3', 'question19', 'question6', 'question4', 'question16', 'question2', 'question9', 'question17', 'question15', 'question13', 'question12', 'question14', 'question18', 'question7']

# %%
q=[]
a=[]
for i in range(1, len([x for x in fields if x.startswith('question')]), 1):
    # if 'question' + str(i) in result['analyzeResult']['documentResults'][0]['fields']:
    if i != 14:
        Name = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]
        Name = get_key(fields, Name)
        NameValue = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]['text']
        q.append(Name)
        a.append(NameValue)

for s in range(1, len([x for x in fields if x.startswith('answer')]), 1):
    Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(s)]

    if Name != None:

        Name = get_key(fields, Name)
        NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(s)]['text']
        q.append(Name)
        a.append(NameValue)
    else:
        result['analyzeResult']['documentResults'][0]['fields']['answer' + str(s)] = {'type': 'string',
                                                                                      'valueString': 'Y',
                                                                                      'text': 'Y',
                                                                                      'page': 1,
                                                                                      'boundingBox': [],
                                                                                      'confidence': 0,
                                                                                      'elements': []}
        NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(s)]['text']
        q.append('answer' + str(s))
        a.append(NameValue)
dict(zip(q, a))
# Out:
# {'question1': 'Has each job been designed to provide a variety of tasks throughout the day in terms of physical and mental workload?',
#  'question2': 'Are highly repetitive tasks (such as keying) performed for more than 2 hours at any one time?',
#  'question3': 'Do tasks require constant sitting or standing for more than 2 hours at any one time?',
#  'question4': 'Are tasks that require a high level of concentration performed for more than 2 hours at any one time?',
#  'question5': 'Do workers have some choice of when, how and how frequently they perform some tasks or are these determined by the equipment or machine they use or by their supervisor?',
#  'question6': 'Are workers trained to vary tasks and postures through the day?',
#  'question7': 'Are individuals given feedback regarding their work performance?',
# ...

# %%
from collections import Counter

analysed_Json = []
q = []
a = []
blob_list = container_client.list_blobs()
for blob in blob_list:
    analysed_Json.append(blob.name)

len_list=len(analysed_Json)
finalData={}
UpdatedDate=[]

for l in range(0, len_list, 1):

    fileName = analysed_Json[l]
    download_stream = container_client.download_blob(fileName)
    jsonData = download_stream.readall()
    result = json.loads(jsonData)
    fields = result['analyzeResult']['documentResults'][0]['fields']
    UpdatedDate.append(result['lastUpdatedDateTime'][0:-10])
    for i in range(1, len([x for x in fields if x.startswith('question')]), 1):
        if i != 14:
            Name = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]
            Name = get_key(fields, Name)
            NameValue = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]['text']
            q.append(Name)
            a.append(NameValue)

    for s in range(1, len([x for x in fields if x.startswith('answer')]), 1):
        Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(s)]

        if Name != None:

            Name = get_key(fields, Name)
            NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(s)]['text']
            q.append(Name)
            a.append(NameValue)
        else:
            result['analyzeResult']['documentResults'][0]['fields']['answer' + str(s)] = {'type': 'string',
                                                                                          'valueString': 'Y',
                                                                                          'text': 'Y',
                                                                                          'page': 1,
                                                                                          'boundingBox': [],
                                                                                          'confidence': 0,
                                                                                          'elements': []}
            NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(s)]['text']
            q.append('answer' + str(s))
            a.append(NameValue)

    finalData[analysed_Json[l]] = (dict(zip(q, a)))

# JobDescription,HMT,Lightning,Noise =[],[],[],[]
JobDescription = []
HMT = []
Lighting = []
Noise = []

for le in range(0, len_list, 1):
    data = finalData[analysed_Json[le]]
    for i in range(1, 5, 1):
        if 'answer' + str(i) in data:
            JobDescription.append(data['answer' + str(i)])

    for i in range(6, 10, 1):
        if 'answer' + str(i) in data:
            HMT.append(data['answer' + str(i)])

    for i in range(11, 15, 1):
        if 'answer' + str(i) in data:
            Lighting.append(data['answer' + str(i)])

    for i in range(16, 19, 1):
        if 'answer' + str(i) in data:
            Noise.append(data['answer' + str(i)])

Category = ["JobDescription", "HMT", "Lighting", "Noise"]
Checked = [JobDescription.count('Y'), HMT.count('Y'), Lighting.count('Y'), Noise.count('Y')]

Category_total = ["JobDescription_total", "HMT_total", "Lighting_total", "Noise_total"]
Checked_total = [len(JobDescription), len(HMT), len(Lighting), len(Noise)]

date_=list(set(UpdatedDate))
DateCount=[]
for i in range(0,len(date_),1):
    DateCount.append({"date":date_[i],"Count":list(dict(Counter(UpdatedDate)).values())[i]})

output = ["Total", "Checked","Date","DateCountList"]
output_total = [dict(zip(Category_total, Checked_total)), (dict(zip(Category, Checked))),sorted(list(set(UpdatedDate))),DateCount]

ChartData = (dict(zip(output, output_total)))
ChartData
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6e06d3d0a034> in <module>
#      24             Name = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]
#      25             Name = get_key(fields, Name)
# ---> 26             NameValue = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]['text']
#      27             q.append(Name)
#      28             a.append(NameValue)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
sorted(list(dict(Counter(UpdatedDate)).values()))
# Out:
# [1]

# %%
type(ChartData['DateCountList'][1])
# Out:
# dict

# %%
UpdatedDate.append(result['lastUpdatedDateTime'][0:-12])
UpdatedDate
# Out:
# ['2020-08-19', '2020-08-']

# %%
"datalist={"Categogy": "Job Description","Checked":JobDescription.count('Y')}
datalist1
# Out:
#   File "<ipython-input-19-b9fa6759b8df>", line 1
#     "datalist={"Categogy": "Job Description","Checked":JobDescription.count('Y')}
#                 ^
# SyntaxError: invalid syntax

# %%
# JobDescription,HMT,Lightning,Noise =[],[],[],[]
JobDescription=[] 
HMT=[]
Lighting=[]
Noise=[]



for l in range(0,6,1):
    data = finalData[analysed_Json[l]]
    for i in range(1,5,1):
        JobDescription.append(data['answer' + str(i)])

    for i in range(6,10,1):
        HMT.append(data['answer' + str(i)])

    for i in range(11,15,1):
        Lighting.append(data['answer' + str(i)])

    for i in range(16,19,1):
        Noise.append(data['answer' + str(i)])

Category=["JobDescription","HMT","Lighting","Noise"]
Checked=[JobDescription.count('Y'),HMT.count('Y'),Lighting.count('Y'),Noise.count('Y')]

Category_total=["JobDescription_total","HMT_total","Lighting_total","Noise_total"]
Checked_total=[len(JobDescription),len(HMT),len(Lighting),len(Noise)]


output=["Total","Checked"]
output_total=[dict(zip(Category_total, Checked_total)),(dict(zip(Category, Checked)))]

ChartData=(dict(zip(output,output_total)))   
ChartData
# Out:
# {'Total': {'JobDescription_total': 24,
#   'HMT_total': 24,
#   'Lighting_total': 24,
#   'Noise_total': 18},
#  'Checked': {'JobDescription': 6, 'HMT': 12, 'Lighting': 12, 'Noise': 18}}

# %%
HMT=[]
for l in range(0,5,1):
    data = finalData[analysed_Json[l]]
    for i in range(6,10,1):
        HMT.append(data['answer' + str(i)])
HMT
# Out:
# ['X',
#  'Y',
#  'Y',
#  'X',
#  'X',
#  'Y',
#  'Y',
#  'X',
#  'X',
#  'Y',
#  'Y',
#  'X',
#  'X',
#  'Y',
#  'Y',
#  'X',
#  'X',
#  'Y',
#  'Y',
#  'X']

# %%
Lighting=[]
for l in range(0,5,1):
    data = finalData[analysed_Json[l]]
    for i in range(11,15,1):
        Lighting.append(data['answer' + str(i)])
 
Lighting.count("Y")
# Out:
# 10

# %%
Noise=[]
for l in range(0,5,1):
    data = finalData[analysed_Json[l]]
    for i in range(16,19,1):
        Noise.append(data['answer' + str(i)])
Noise.count("Y")
# Out:
# 15

# %%
analysed_Json = []
blob_list = container_client.list_blobs()
for blob in blob_list:
    analysed_Json.append(blob.name)

    fileName = analysed_Json[0]


download_stream = container_client.download_blob(fileName)
jsonData = download_stream.readall()
result = json.loads(jsonData)
global JsonResult
JsonResult=result
fields = result['analyzeResult']['documentResults'][0]['fields']
q = []
a = []
q.append("FileName");
# a.append(analysed_Json[int(resp['page'])])
a.append(analysed_Json)
size=len(analysed_Json)
print(size)

for l in range(1,size,1):   
    
    for s in range(1, 14, 1):
        Name = result['analyzeResult']['documentResults'][0]['fields']['question' + str(s)]
        Name = get_key(fields,Name)
        NameValue = result['analyzeResult']['documentResults'][0]['fields']['question' + str(s)]['text']
        q.append(Name)
        a.append(NameValue)

    for i in range(1, 19, 1):
        Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]
        for i in range(1, 19, 1):
            Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]
            if Name != None:
                Name = get_key(fields,Name)
                NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]['text']
                q.append(Name)
                a.append(NameValue)
            else:
                result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)] = {'type': 'string',
                                                                                                  'valueString': 'Y',
                                                                                                  'text': 'Y',
                                                                                                  'page': 1,
                                                                                                  'boundingBox': [],
                                                                                                  'confidence': 0,
                                                                                                  'elements': []}
                NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]['text']
                q.append('answer' + str(i))
                a.append(NameValue)

finalData={}
finalData["Ash"]=(dict(zip(q, a)))
# Out:
# 6

# %%
download_stream = container_client.download_blob(analysed_Json[0])
jsonData = download_stream.readall()
result = json.loads(jsonData)
result
# Out:
# {'status': 'succeeded',
#  'createdDateTime': '2020-07-30T14:01:07Z',
#  'lastUpdatedDateTime': '2020-07-30T14:01:15Z',
#  'analyzeResult': {'version': '2.0.0',
#   'readResults': [{'page': 1,
#     'language': 'en',
#     'angle': 0,
#     'width': 8.5,
#     'height': 11,
#     'unit': 'inch',
#     'lines': [{'boundingBox': [1.0109,
#        1.0952,
#        1.4542,
#        1.0952,
#        1.4542,
#        1.2073,
#        1.0109,
#        1.2073],
#       'text': 'Name:',
#       'words': [{'boundingBox': [1.0109,
#          1.0952,
#          1.4542,
#          1.0952,
#          1.4542,
#          1.2073,
#          1.0109,
#          1.2073],
#         'text': 'Name:',
#         'confidence': 1}]},
#      {'boundingBox': [1.4967,
#        0.9867,
#        2.7433,
#        1.0133,
#        2.74,
#        1.1767,
#        1.4933,
#        1.15],
#       'text': 'Sheldon Cooper',
#       'words': [{'boundingBox': [1.5294,
#          0.9905,
#          2.1326,
# ...

# %%
r=[]
t=[]
for i in range(1, 25, 1): 
    Name = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]
    if Name !=None:
        Name = get_key(fields,Name)
        NameValue = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]['text']
        r.append(Name)
        t.append(NameValue)
    else:
        break;

# %%
Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]
len(Name)
# Out:
# 7

# %%
for i in range(1, 18, 1):
    Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]

    if Name == None:
        print(1)
        Name = get_key(fields,Name)
        NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]['text']='yes'
        r.append(Name)
        t.append(NameValue)

# %%
Name
# Out:
# {'type': 'string',
#  'valueString': 'Y',
#  'text': 'Y',
#  'page': 1,
#  'boundingBox': [],
#  'confidence': 0,
#  'elements': []}

# %%
finalData = dict(zip(r, t))
finalData
# Out:
# {'question1': 'Has each job been designed to provide a variety of tasks throughout the day in terms of physical and mental workload?',
#  'question2': 'Are highly repetitive tasks (such as keying) performed for more than 2 hours at any one time?',
#  'question3': 'Do tasks require constant sitting or standing for more than 2 hours at any one time?',
#  'question4': 'Are tasks that require a high level of concentration performed for more than 2 hours at any one time?',
#  'question5': 'Do workers have some choice of when, how and how frequently they perform some tasks or are these determined by the equipment or machine they use or by their supervisor?',
#  'question6': 'Are workers trained to vary tasks and postures through the day?',
#  'question7': 'Are individuals given feedback regarding their work performance?',
# ...

# %%
analysed_Json = []
blob_list = container_client.list_blobs()
for blob in blob_list:
    analysed_Json.append(blob.name)
global fileName

download_stream = container_client.download_blob(analysed_Json[0])
jsonData = download_stream.readall()
result = json.loads(jsonData)
global JsonResult
JsonResult=result
fields = result['analyzeResult']['documentResults'][0]['fields']
q = []
a = []
q.append("FileName");
finalData={}

# a.append(analysed_Json[int(resp['page'])])
a.append(analysed_Json)
Name = result['analyzeResult']['documentResults'][0]['fields']['Name']
Name = get_key(fields,Name)
NameValue = result['analyzeResult']['documentResults'][0]['fields']['Name']['text']
q.append(Name)
a.append(NameValue)
Name = result['analyzeResult']['documentResults'][0]['fields']['Employee Code']
Name = get_key(fields,Name)
NameValue = result['analyzeResult']['documentResults'][0]['fields']['Employee Code']['text']
q.append(Name)
a.append(NameValue)
Name = result['analyzeResult']['documentResults'][0]['fields']['Company']
Name = get_key(fields,Name)
NameValue = result['analyzeResult']['documentResults'][0]['fields']['Company']['text']
q.append(Name)
a.append(NameValue)
for i in range(1, 19, 1):
    if i != 14:
        Name = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]
        Name = get_key(fields,Name)
        NameValue = result['analyzeResult']['documentResults'][0]['fields']['question' + str(i)]['text']
        q.append(Name)
        a.append(NameValue)
for i in range(1, 19, 1):
    Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]
    for i in range(1, 19, 1):
        Name = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]
        if Name != None:
            Name = get_key(fields,Name)
            NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]['text']
            q.append(Name)
            a.append(NameValue)
        else:
            
            result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)] = {'type': 'string',
                                                                                          'valueString': 'Y',
                                                                                          'text': 'Y',
                                                                                           'page': 1,
                                                                                            'boundingBox': [],
                                                                                             'confidence': 0,
                                                                                             'elements': []}
            NameValue = result['analyzeResult']['documentResults'][0]['fields']['answer' + str(i)]['text']
        q.append('answer' + str(i))
        a.append(NameValue)
finalData =  dict(zip(q, a))
GridList={}
data2=[]

data2.append({'id': "1", 'Labels': "Name", 'question': "Name", 'answer': finalData['Name']})
data2.append({'id': "2", 'Labels': "Company", 'question': "Company", 'answer': finalData['Company']})
data2.append({'id': "3", 'Labels': "Employee Code", 'question': "Employee Code",'answer': finalData['Employee Code']})
for d in range(1,19,1):
    if d!=14:
        data2.append({'id': ""+ str(d), 'Labels': "answer"+ str(d), 'question': finalData['question'+ str(d)],'answer': finalData['answer' + str(d)]})
GridList["FileName"]=analysed_Json
GridList['GridData']=data2

GridList
