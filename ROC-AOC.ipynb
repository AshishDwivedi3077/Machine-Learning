# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
A =pd.read_excel("C:\\Users\\Ashish\\Desktop\\DataScience\\Datasets\\Startup.xlsx") 
A.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
import seaborn as sb
sb.pairplot(A)
A.RND.hist()

# %%
E = []
q = np.mean(A.PROFIT)
for i in A.PROFIT:
   if(i < q):
       E.append(0)
   else:
       E.append(1)
q
# Out:
# 112012.63920000002

# %%
A['NP']=E
A
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT  NP
# 0   165349.20  136897.80  471784.10    New York  192261.83   1
# 1   162597.70  151377.59  443898.53  California  191792.06   1
# 2   153441.51  101145.55  407934.54     Florida  191050.39   1
# 3   144372.41  118671.85  383199.62    New York  182901.99   1
# 4   142107.34   91391.77  366168.42     Florida  166187.94   1
# 5   131876.90   99814.71  362861.36    New York  156991.12   1
# 6   134615.46  147198.87  127716.82  California  156122.51   1
# 7   130298.13  145530.06  323876.68     Florida  155752.60   1
# 8   120542.52  148718.95  311613.29    New York  152211.77   1
# 9   123334.88  108679.17  304981.62  California  149759.96   1
# 10  101913.08  110594.11  229160.95     Florida  146121.95   1
# 11  100671.96   91790.61  249744.55  California  144259.40   1
# 12   93863.75  127320.38  249839.44     Florida  141585.52   1
# 13   91992.39  135495.07  252664.93  California  134307.35   1
# ...

# %%
from sklearn.model_selection import train_test_split
X = A[['RND','MKT']]
Y = A[['NP']]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .20, random_state = 20)
A.head(40)
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT  NP
# 0   165349.20  136897.80  471784.10    New York  192261.83   1
# 1   162597.70  151377.59  443898.53  California  191792.06   1
# 2   153441.51  101145.55  407934.54     Florida  191050.39   1
# 3   144372.41  118671.85  383199.62    New York  182901.99   1
# 4   142107.34   91391.77  366168.42     Florida  166187.94   1
# 5   131876.90   99814.71  362861.36    New York  156991.12   1
# 6   134615.46  147198.87  127716.82  California  156122.51   1
# 7   130298.13  145530.06  323876.68     Florida  155752.60   1
# 8   120542.52  148718.95  311613.29    New York  152211.77   1
# 9   123334.88  108679.17  304981.62  California  149759.96   1
# 10  101913.08  110594.11  229160.95     Florida  146121.95   1
# 11  100671.96   91790.61  249744.55  California  144259.40   1
# 12   93863.75  127320.38  249839.44     Florida  141585.52   1
# 13   91992.39  135495.07  252664.93  California  134307.35   1
# ...

# %%
lr = LogisticRegression()
model = lr.fit(X_train,Y_train)
predicted = model.predict(X_test)
# Out:
# C:\Users\Ashish\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,predicted)
# Out:
# array([[2, 3],
#        [0, 5]], dtype=int64)

# %%
lr.predict_proba(X_test)[:,1]
# Out:
# array([0.65298188, 0.80465715, 0.74538397, 0.71122622, 0.50352091,
#        0.72859005, 0.68274681, 0.75835988, 0.5       , 0.31945044])

# %%
import sklearn.metrics as m
m.accuracy_score(Y_test,predicted)
# Out:
# 0.7

# %%
import sklearn.metrics as m
lr = LogisticRegression()
model = lr.fit(X_train,Y_train)
predicted = model.predict(X_test)
# calculate the fpr and tpr for all thresholds of the classification
probs = lr.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = m.roc_curve(Y_test, preds)
roc_auc = m.auc(fpr, tpr)

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, roc_auc)

# %%
roc_auc
# Out:
# 0.8

# %%
print(m.classification_report(Y_test,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57         5
#            1       0.62      1.00      0.77         5
#
#     accuracy                           0.70        10
#    macro avg       0.81      0.70      0.67        10
# weighted avg       0.81      0.70      0.67        10

# %%
import matplotlib.pyplot as plt
plt.plot(fpr,tpr,roc_auc)

# %%
m.classification_report(Y_test,predicted)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      0.40      0.57         5\n           1       0.62      1.00      0.77         5\n\n    accuracy                           0.70        10\n   macro avg       0.81      0.70      0.67        10\nweighted avg       0.81      0.70      0.67        10\n'

# %%
m.roc_curve(Y_test,lr.predict_proba(X_test)[:,1])
# Out:
# (array([0. , 0. , 0.2, 0.2, 0.4, 0.4, 1. ]),
#  array([0. , 0.2, 0.2, 0.8, 0.8, 1. , 1. ]),
#  array([1.80465715, 0.80465715, 0.75835988, 0.71122622, 0.68274681,
#         0.65298188, 0.31945044]))
