# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

A=pd.read_csv(r"C:\Users\ashishkumd2\Desktop\SOurcs\ML\Datsets\hitters.csv")

#A = pd.read_csv("/users/bajajvbh/Desktop/Vaibhav/Datasets/.csv")

# %%
A.head(1)
#A..unique
# Out:
#        Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  \
# 0  -Andy Allanson    293    66      1    30   29     14      1     293     66
#
#    ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  Salary  \
# 0  ...     30    29      14       A        E     446       33      20     NaN
#
#    NewLeague
# 0          A
#
# [1 rows x 21 columns]

# %%
A.tomorrow.unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f887821b4f7f> in <module>
# ----> 1 A.tomorrow.unique
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tomorrow'

# %%
for i in A.columns:
    if(A[i].dtypes=="object"):
        sb.boxplot(A[i],A.Salary)
        plt.show()
    else:
        sb.scatterplot(A.Salary,A[i])
        plt.show()

# %%
A.columns
# Out:
# Index(['Unnamed: 0', 'AtBat', 'Hits', 'HmRun', 'Runs', 'RBI', 'Walks', 'Years',
#        'CAtBat', 'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks', 'League',
#        'Division', 'PutOuts', 'Assists', 'Errors', 'Salary', 'NewLeague'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X = pd.DataFrame(ss.fit_transform(A[["CAtBat","AtBat"]]),columns=["CAtBat","AtBat"])

#A = A.drop(labels=["Unnamed: 0"],axis=1)
#A.Salary.mean()
A.Salary=A.Salary.fillna(535.92)
Y = A[["Salary"]]
X
# Out:
#        CAtBat     AtBat
# 0   -1.015121 -0.574071
# 1    0.344876 -0.430437
# 2   -0.441561  0.640293
# 3    1.283860  0.751283
# 4   -0.970736 -0.391264
# ..        ...       ...
# 317  0.023406  0.757812
# 318  1.233441  0.725167
# 319 -0.408811  0.614177
# 320  0.236714  1.254003
# 321  0.973594  1.632676
#
# [322 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=30)

from sklearn.neighbors import KNeighborsRegressor
knn= KNeighborsRegressor(n_neighbors=11)
model = knn.fit(xtrain,ytrain)
pred = model.predict(xtest)
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)
X
# Out:
#        CAtBat     AtBat
# 0   -1.015121 -0.574071
# 1    0.344876 -0.430437
# 2   -0.441561  0.640293
# 3    1.283860  0.751283
# 4   -0.970736 -0.391264
# ..        ...       ...
# 317  0.023406  0.757812
# 318  1.233441  0.725167
# 319 -0.408811  0.614177
# 320  0.236714  1.254003
# 321  0.973594  1.632676
#
# [322 rows x 2 columns]

# %%
from sklearn.model_selection import GridSearchCV
tp = {"n_neighbors":range(2,20,1)}
knn = KNeighborsRegressor()
cv = GridSearchCV(knn,tp,scoring="neg_mean_absolute_error",cv=5)
cvmodel = cv.fit(xtrain,ytrain)
cvmodel.best_params_
# Out:
# {'n_neighbors': 11}

# %% [markdown]
# # Classfication

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
A =pd.read_csv("C:\\Users\\Ashish\\Desktop\\DataScience\\Datasets\\Cars93.csv") 
A.head(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-633d7765368a> in <module>
#       2 import numpy as np
#       3 from sklearn.linear_model import LogisticRegression
# ----> 4 A =pd.read_csv("C:\\Users\\Ashish\\Desktop\\DataScience\\Datasets\\Cars93.csv")
#       5 A.head(2)
#
# ...

# %%
Y = A[["Type"]]
X = A.drop(labels=["Unnamed: 0","Model","Make","Type"],axis=1)

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X = X.apply(le.fit_transform)

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=20)

from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=5)
model = knn.fit(xtrain,ytrain)
pred = model.predict(xtest)

from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3638106e2857> in <module>
# ----> 1 Y = A[["Type"]]
#       2 X = A.drop(labels=["Unnamed: 0","Model","Make","Type"],axis=1)
#       3
#       4 from sklearn.preprocessing import LabelEncoder
#       5 le = LabelEncoder()
#
# NameError: name 'A' is not defined

# %%
from sklearn.model_selection import GridSearchCV
tp = {"n_neighbors":range(2,20,1)}
knn = KNeighborsClassifier()
cv = GridSearchCV(knn,tp,scoring="accuracy",cv=5)
cvmodel = cv.fit(xtrain,ytrain)
# Out:
# C:\Users\Ashish\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Ashish\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Ashish\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
cvmodel.best_params_
# Out:
# {'n_neighbors': 5}
