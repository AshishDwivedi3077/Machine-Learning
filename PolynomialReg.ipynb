# %%
import pandas as pd
A = pd.read_csv(r"C:\Users\ashishkumd2\Desktop\SOurcs\ML\Datsets/Credit.csv")

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
OL=[]
import numpy as np
for i in ss.fit_transform(A[["Income"]]):
   print("%.2f"%np.abs(i))
   if(i>3):
       OL.append(i)
# Out:
# 0.86
# 1.73
# 1.69
# 2.95
# 0.30
# 0.99
# 0.69
# 0.74
# 0.85
# 0.73
# 0.51
# 0.86
# 1.01
# 0.04
# 0.74
# 0.71
# 0.24
# 0.25
# 0.12
# 0.09
# 0.78
# 0.22
# 0.71
# 0.53
# 0.98
# 0.88
# 0.08
# 0.35
# 4.02
# 0.52
# 0.31
# 0.46
# 2.53
# 0.39
# 0.71
# 0.62
# 0.49
# 0.43
# 0.95
# 0.90
# 0.29
# 1.94
# 0.03
# 0.24
# 0.38
# 0.91
# 0.73
# 0.02
# 0.02
# 0.05
# 0.25
# 0.16
# 0.03
# 0.82
# 0.85
# 0.35
# 0.34
# 0.88
# 0.99
# 0.19
# 0.28
# 0.68
# 0.41
# 0.88
# 0.37
# 0.94
# 1.95
# 0.97
# 0.49
# 0.12
# 0.58
# 0.39
# 0.63
# 0.60
# 0.83
# 0.35
# 0.41
# 0.69
# 1.87
# 0.85
# 0.51
# 0.23
# 0.61
# 0.74
# 0.05
# 3.04
# 0.29
# 0.95
# 0.84
# 0.41
# 0.71
# 0.09
# 0.41
# 0.82
# 0.20
# 0.88
# 0.88
# 0.54
# 0.25
# 1.10
# 0.68
# 0.77
# 0.67
# 2.87
# 0.83
# 0.94
# 0.81
# 0.17
# 1.78
# 0.90
# 0.30
# 0.47
# 0.02
# 0.68
# 0.82
# 0.14
# 0.29
# 1.31
# 0.52
# 0.63
# 0.51
# 2.92
# 0.49
# 0.95
# 0.44
# 0.50
# 0.53
# 0.34
# 2.22
# 0.77
# 0.61
# 0.98
# 0.62
# 0.68
# 0.30
# 0.02
# 0.27
# 0.25
# 0.68
# 1.78
# 0.15
# 1.33
# ...

# %%
A.describe()
# Out:
#        Unnamed: 0          ID      Income         Limit      Rating  \
# count  400.000000  400.000000  400.000000    400.000000  400.000000
# mean   200.500000  200.500000   45.218885   4735.600000  354.940000
# std    115.614301  115.614301   35.244273   2308.198848  154.724143
# min      1.000000    1.000000   10.354000    855.000000   93.000000
# 25%    100.750000  100.750000   21.007250   3088.000000  247.250000
# 50%    200.500000  200.500000   33.115500   4622.500000  344.000000
# 75%    300.250000  300.250000   57.470750   5872.750000  437.250000
# max    400.000000  400.000000  186.634000  13913.000000  982.000000
#
#             Cards         Age   Education      Balance
# count  400.000000  400.000000  400.000000   400.000000
# mean     2.957500   55.667500   13.450000   520.015000
# std      1.371275   17.249807    3.125207   459.758877
# min      1.000000   23.000000    5.000000     0.000000
# 25%      2.000000   41.750000   11.000000    68.750000
# ...

# %% [markdown]
# # # Polynomial Regression#

# %% [raw]
# Y ~ X
# Y ~ X^2
#
# Area of circle, radius
#
# Area of circle ~ radius
#
# Area of circle ~ radius^2

# %% [raw]
# Prior Domain knowledge on polynomial degree

# %%
A = pd.read_csv(r"C:\Users\ashishkumd2\Desktop\SOurcs\ML\Datsets\poly.csv")
X = A[['X']]
Y = A[['Y']]

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

poly = PolynomialFeatures(degree = 2)
X_square = poly.fit_transform(X)

plm = LinearRegression()
W = plm.fit(X_square,Y)

# %%
# Visualising the Polynomial Regression results
plt.scatter(X,Y, color = 'blue')
plt.plot(X,plm.predict(X_square), color = 'red')
plt.title('Polynomial Regression')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %% [raw]
# Does changing degree of polynomial lead to underfitting/overfitting of a model
