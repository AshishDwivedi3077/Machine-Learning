# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
A =pd.read_excel("C://Users//Ashish//Desktop//DataScience/fsw.xlsx",set_index='PART NUMBER') 
A.set_index(['PART NUMBER'])
X=A.iloc[:,2].values
Y=A.iloc[2:12,3].values
Y
# Out:
# array(['CPDC', 'DCEC', 'GCIC', 'CPDC', 'CPDC', 'CPDC', 'BFCEC', 'DCEC',
#        'BFCEC', 'JEP'], dtype=object)

# %%
A.isna().sum().plot(kind="barh")
#A.info.plot(kind="barh")

# %%
A['May-19'].isin([1]).any()#.sum()#.plot(kind='bar')
# Out:
# True

# %%
0 in A['May-19'].values
# Out:
# True

# %%
A[['May-19']]==1
# Out:
#      May-19
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ..      ...
# 131   False
# 132   False
# 133   False
# 134   False
# 135   False
#
# [136 rows x 1 columns]

# %%
import missingno as mo
mo.bar(A)
mo.matrix(A)

# %%
A.replace(0,'Nan',inplace=True)

# %%
A.head(0)
# Out:
# Empty DataFrame
# Columns: [ORGANIZATION NAME, PART NUMBER, DESCRIPTION, CUSTOMER NAME, Dec-18, Jan-19, Feb-19, Mar-19, Apr-19, May-19, Jun-19, Jul-19, Aug-19, Sep-19, Oct-19, Nov-19, Dec-19, Jan-20, Feb-20, Mar-20, Apr-20, May-20, Jun-20, Jul-20, Aug-20, Sep-20, Oct-20, Nov-20, Dec-20, Jan-21, Feb-21, Mar-21, Apr-21, May-21, Jun-21, Jul-21, Aug-21, Sep-21, Oct-21, Nov-21]
# Index: []
#
# [0 rows x 40 columns]

# %%
import seaborn as sb

# %%
sb.countplot(A['PART NUMBER'])

# %%
#sb.distplot(A['Dec-18'])
int(A.Dec-18)#.asdtype('int')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-4a42c83ecebc> in <module>
#       1 #sb.distplot(A['Dec-18'])
# ----> 2 int(A.Dec-18)#.asdtype('int')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Dec'

# %%
A.replace(0,'NaN',inplace=True)
sb.heatmap(A.isin([0]),linecolor='red',cbar=True,)

# %%
A.isnull().sum()

# %%
A

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
Y=A.iloc[0:1].values
Y
Y
# Out:
# array([['FSW', '5491659', 'WHTC Injector', 'DCEC', 'Nan', 'Nan', 'Nan',
#         'Nan', 'Nan', 480, 480, 390, 480, 570, 540, 510, 480, 'Nan',
#         'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan',
#         'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan',
#         'Nan', 'Nan', 'Nan', 'Nan']], dtype=object)

# %%
col = []
for i in A.columns:
    col.append(i)
col.remove('ORGANIZATION NAME')#, 'PART NUMBER', 'DESCRIPTION', 'CUSTOMER NAME'
col.remove('PART NUMBER')
col.remove('DESCRIPTION')
col.remove('CUSTOMER NAME')
col
# Out:
# ['Dec-18',
#  'Jan-19',
#  'Feb-19',
#  'Mar-19',
#  'Apr-19',
#  'May-19',
#  'Jun-19',
#  'Jul-19',
#  'Aug-19',
#  'Sep-19',
#  'Oct-19',
#  'Nov-19',
#  'Dec-19',
#  'Jan-20',
#  'Feb-20',
#  'Mar-20',
#  'Apr-20',
#  'May-20',
#  'Jun-20',
#  'Jul-20',
#  'Aug-20',
#  'Sep-20',
#  'Oct-20',
#  'Nov-20',
#  'Dec-20',
#  'Jan-21',
#  'Feb-21',
#  'Mar-21',
#  'Apr-21',
#  'May-21',
#  'Jun-21',
#  'Jul-21',
#  'Aug-21',
#  'Sep-21',
#  'Oct-21',
#  'Nov-21']

# %%
t=list(zip(col,Y))
df=pd.DataFrame(t)
df
# Out:
#          0              1
# 0   Dec-18            FSW
# 1   Jan-19        5491659
# 2   Feb-19  WHTC Injector
# 3   Mar-19           DCEC
# 4   Apr-19            Nan
# 5   May-19            Nan
# 6   Jun-19            Nan
# 7   Jul-19            Nan
# 8   Aug-19            Nan
# 9   Sep-19            480
# 10  Oct-19            480
# 11  Nov-19            390
# 12  Dec-19            480
# 13  Jan-20            570
# 14  Feb-20            540
# 15  Mar-20            510
# 16  Apr-20            480
# 17  May-20            Nan
# 18  Jun-20            Nan
# 19  Jul-20            Nan
# 20  Aug-20            Nan
# 21  Sep-20            Nan
# 22  Oct-20            Nan
# 23  Nov-20            Nan
# 24  Dec-20            Nan
# 25  Jan-21            Nan
# 26  Feb-21            Nan
# 27  Mar-21            Nan
# 28  Apr-21            Nan
# 29  May-21            Nan
# 30  Jun-21            Nan
# 31  Jul-21            Nan
# 32  Aug-21            Nan
# 33  Sep-21            Nan
# ...

# %%
Y=['FSW', '5491659', 'WHTC Injector', 'DCEC', 'Nan', 'Nan', 'Nan',
        'Nan', 'Nan', 480, 480, 390, 480, 570, 540, 510, 480, 'Nan',
        'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan',
        'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan',
        'Nan', 'Nan', 'Nan', 'Nan']
Y.remove([])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-d4d708ddefff> in <module>
#       4         'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan', 'Nan',
#       5         'Nan', 'Nan', 'Nan', 'Nan']
# ----> 6 Y.remove([])
#
# ValueError: list.remove(x): x not in list

# %%
sale.remove(0)
sale
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-2d47f44c7c5f> in <module>
# ----> 1 sale.remove(0)
#       2 sale
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
Y
# Out:
# ['FSW',
#  '5491659',
#  'WHTC Injector',
#  'DCEC',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  480,
#  480,
#  390,
#  480,
#  570,
#  540,
#  510,
#  480,
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan',
#  'Nan']
