# %%
########### Python Form Recognizer Async Analyze #############
import json
import time
from requests import get, post
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
blob_service_client = BlobServiceClient.from_connection_string('DefaultEndpointsProtocol=https;AccountName=checklistform;AccountKey=dpZeiTIELCgVGxRxqYkhqAx42b8pWND2onchJ83+yXgHqbkMkPS5aKbmmVMtdDJdENFmmH3EuHhANmUQ02d7TQ==;EndpointSuffix=core.windows.net')
from urllib.request import urlopen


# Endpoint URL
endpoint = r"https://checklistformreader.cognitiveservices.azure.com"
apim_key = "e8e591d41a0b43bf8f21da161c204ad2"
model_id='62a96766-80f6-4c23-867b-af07a527d9da'
post_url = endpoint + "/formrecognizer/v2.0/custom/models/%s/analyze" % model_id
source = r"C:\Users\ashishkumd2\Desktop\PowerApps\AleSodte_Workspace.pdf"

C:\Users\ashishkumd2\Desktop\PowerApps\AATestRoss_Workspace.pdf
    
    
# source = urlopen( 'https://checklistform.blob.core.windows.net/editedjson/AATEst.pdf')

blob_client = blob_service_client.get_container_client("forms")


params = {
    "includeTextDetails": True
}
headers = {
    # Request headers
    'Content-Type': 'application/pdf',
        'Ocp-Apim-Subscription-Key': apim_key,
}

with open(source, "rb") as f:
    data_bytes = f.read()
    blob_client.upload_blob("AAAAAATEst.pdf",f,overwrite=True)
    print("Doneeeeeeeeee")
    
try:
    resp = post(url = post_url, data = data_bytes, headers = headers, params = params)
    if resp.status_code != 202:
        print("POST analyze failed:\n%s" % resp.json())
        quit()
    print("POST analyze succeeded:")
    get_url = resp.headers["operation-location"]
    n_tries = 6
    n_try = 0
    wait_sec = 5
    max_wait_sec = 60
    while n_try < n_tries:
        resp_analised = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
        resp_json = resp_analised.json()
        if resp_analised.status_code != 200:
            print("GET analyze results failed:\n%s" % json.dumps(resp_json))
        status = resp_json["status"]
        if status == "succeeded":
            print("Analysis succeeded:")
            global AnaysedData
            AnaysedData= json.dumps(resp_json)
           
        if status == "failed":
            print("Analysis failed:\n%s" % json.dumps(resp_json)) 
        n_try += 1
#################--upload pdf from URL--########################################


#         blob_client.upload_blob("AAAAAAAAAAAAA.pdf",source,overwrite=True)
        
#################--upload pdf from FilePath--########################################
   
        
#################--upload JSON--########################################
    blob_client = blob_service_client.get_container_client("analizedforms")
    blob_client.upload_blob("Test21.json", AnaysedData, overwrite=True)
    
    print(AnaysedData)
except Exception as e:
    print("POST analyze failed:\n%s" % str(e))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b3706c053a3c> in <module>
#      30 with open(source, "rb") as f:
#      31     data_bytes = f.read()
# ---> 32     blob_client.upload_blob("AAAAAATEst.pdf",f,overwrite=True)
#      33     print("Doneeeeeeeeee")
#      34
#
# ~\Anaconda3\lib\site-packages\azure\core\tracing\decorator.py in wrapper_use_tracer(*args, **kwargs)
#      81             span_impl_type = settings.tracing_implementation()
#      82             if span_impl_type is None:
# ---> 83                 return func(*args, **kwargs)
#      84
#      85             # Merge span is parameter is set, but only if no explicit parent are passed
#
# ~\Anaconda3\lib\site-packages\azure\storage\blob\_container_client.py in upload_blob(self, name, data, blob_type, length, metadata, **kwargs)
#     840         timeout = kwargs.pop('timeout', None)
# ...

# %%
from urllib.request import urlopen
data = urlopen( 'https://checklistform.blob.core.windows.net/editedjson/AATEst.pdf')

# %%
data

# %%
def GetAnalysedJson():
    n_tries = 3
    n_try = 0
    wait_sec = 5
    max_wait_sec = 60
    while n_try < n_tries:
        resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
        resp_json = resp.json()
        if resp.status_code != 200:
            print("GET analyze results failed:\n%s" % json.dumps(resp_json))
        status = resp_json["status"]
        if status == "succeeded":
            print("Analysis succeeded:")
            global AnaysedData
            AnaysedData= json.dumps(resp_json)
        if status == "failed":
            print("Analysis failed:\n%s" % json.dumps(resp_json)) 
        n_try += 1
    print(AnaysedData)
    return AnaysedData

# %%
n_tries = 3
n_try = 0
wait_sec = 5
max_wait_sec = 60
while n_try < n_tries:
    try:
        resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
        resp_json = resp.json()
        if resp.status_code != 200:
            print("GET analyze results failed:\n%s" % json.dumps(resp_json))
#             quit()
        status = resp_json["status"]
        if status == "succeeded":
            print("Analysis succeeded:")
            AnaysedData= json.dumps(resp_json)
#             quit()
        if status == "failed":
            print("Analysis failed:\n%s" % json.dumps(resp_json))
            quit()
        # Analysis still running. Wait and retry.
#         time.sleep(wait_sec)
        n_try += 1
#         wait_sec = min(2*wait_sec, max_wait_sec)     
    except Exception as e:
        msg = "GET analyze results failed:\n%s" % str(e)
        print(msg)
#         quit()
AnaysedData
# Out:
# Analysis succeeded:
# Analysis succeeded:
# ...

# %%
########### Python Form Recognizer Async Analyze #############
import json
import time
from requests import get, post



# Endpoint URL
endpoint = r"https://checklistformreader.cognitiveservices.azure.com"
apim_key = "e8e591d41a0b43bf8f21da161c204ad2"
model_id='62a96766-80f6-4c23-867b-af07a527d9da'
post_url = endpoint + "/formrecognizer/v2.0/custom/models/%s/analyze" % model_id

source = r"C:\Users\ashishkumd2\Desktop\PowerApps\AleSodte_Workspace.pdf"
params = {
    "includeTextDetails": True
}
headers = {
    # Request headers
    'Content-Type': 'application/pdf',
        'Ocp-Apim-Subscription-Key': apim_key,
}

with open(source, "rb") as f:
    data_bytes = f.read()
try:
    resp = post(url = post_url, data = data_bytes, headers = headers, params = params)
    if resp.status_code != 202:
        print("POST analyze failed:\n%s" % resp.json())
        quit()
    print("POST analyze succeeded:\n%s" % resp.headers)
    get_url = resp.headers["operation-location"]
except Exception as e:
    print("POST analyze failed:\n%s" % str(e))
    #quit()
# Out:
# POST analyze succeeded:
# {'Content-Length': '0', 'Operation-Location': 'https://checklistformreader.cognitiveservices.azure.com/formrecognizer/v2.0/custom/models/62a96766-80f6-4c23-867b-af07a527d9da/analyzeresults/877c4aad-a071-4525-be99-11162843ef8a', 'x-envoy-upstream-service-time': '5208', 'apim-request-id': '21ccd51e-6a8f-4337-b719-698f83163ab2', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'Date': 'Fri, 14 Aug 2020 05:07:25 GMT'}

# %%
n_tries = 3
n_try = 0
wait_sec = 5
max_wait_sec = 60
while n_try < n_tries:
    try:
        resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
        resp_json = resp.json()
        if resp.status_code != 200:
            print("GET analyze results failed:\n%s" % json.dumps(resp_json))
            quit()
        status = resp_json["status"]
        if status == "succeeded":
            print("Analysis succeeded:")

            AnaysedData= json.dumps(resp_json)
            quit()
        if status == "failed":
            print("Analysis failed:\n%s" % json.dumps(resp_json))
            quit()
        # Analysis still running. Wait and retry.
        time.sleep(wait_sec)
        n_try += 1
        wait_sec = min(2*wait_sec, max_wait_sec)     
    except Exception as e:
        msg = "GET analyze results failed:\n%s" % str(e)
        print(msg)
        quit()
# Out:
# Analysis succeeded:
# ...

# %%
AnaysedData

# %%
########### Python Form Recognizer Labeled Async Train #############
import json
import time
from requests import get, post

# Endpoint URL
endpoint = r"https://checklistformreader.cognitiveservices.azure.com"
post_url = endpoint +"/formrecognizer/v2.0/custom/models"

source = r"https://checklistform.blob.core.windows.net/forms?sv=2019-12-12&ss=bfqt&srt=sco&sp=rwdlacupx&se=2020-10-10T15:57:03Z&st=2020-08-10T07:57:03Z&spr=https&sig=FUzRqprVHA24kRPcDSQS65LtWionvB29ZGcyvGbnKRs%3D"
prefix = ""
includeSubFolders = False
useLabelFile = False

headers = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': 'e8e591d41a0b43bf8f21da161c204ad2',
}

body =     {
    "source": source,
    "sourceFilter": {
        "prefix": prefix,
        "includeSubFolders": includeSubFolders
    },
    "useLabelFile": useLabelFile
}

try:
    resp_1 = post(url = post_url, json = body, headers = headers)
    #print("-------> ",post_url)
    if resp_1.status_code != 201:
        print("POST model failed (%s):\n%s" % (resp_1.status_code, json.dumps(resp_1.json())))
        quit()
    print("POST model succeeded:\n%s" % resp_1.headers)
    get_url = resp_1.headers["location"]
except Exception as e:
    print("POST model failed:\n%s" % str(e))
    quit()
# Out:
# POST model succeeded:
# {'Content-Length': '0', 'Location': 'https://checklistformreader.cognitiveservices.azure.com/formrecognizer/v2.0/custom/models/57c42e6f-75c5-4186-a484-490db47ad3e8', 'x-envoy-upstream-service-time': '334', 'apim-request-id': 'bb64f856-2aaf-4a83-8c8c-df9fee2ee609', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'Date': 'Sat, 15 Aug 2020 07:36:14 GMT'}

# %%
get_url
# Out:
# 'https://checklistformreader.cognitiveservices.azure.com/formrecognizer/v2.0/custom/models/57c42e6f-75c5-4186-a484-490db47ad3e8'

# %%
n_tries = 2
n_try = 0
wait_sec = 5
max_wait_sec = 60
while n_try < n_tries:
    try:
        resp = get(url = get_url, headers = headers)
        resp_json = resp.json()
        #print("---------->",get_url )
        if resp.status_code != 200:
            print("\n GET model failed (%s):\n%s" % (resp.status_code, json.dumps(resp_json)))
            quit()
        model_status = resp_json["modelInfo"]["status"]
        if model_status == "ready":
            print("\n Training succeeded:\n%s" % json.dumps(resp_json))
            #quit()
        if model_status == "invalid":
           # print("&&&&&&&&&&&", resp_json)
            print("\n Training failed. Model is invalid:\n%s" % json.dumps(resp_json))
            #quit()
        # Training still running. Wait and retry.
        time.sleep(wait_sec)
        n_try += 1
        wait_sec = min(2*wait_sec, max_wait_sec)     
    except Exception as e:
        msg = "GET model failed:\n%s" % str(e)
        print(msg)
       # quit()
print("Train operation did not complete within the allocated time.")
# Out:
#  Training succeeded:
# ...

# %%
resp_json['modelInfo']['modelId']
# model_id
# Out:
# '57c42e6f-75c5-4186-a484-490db47ad3e8'

# %%
uurl=resp_1.headers['Location']
body
headers
# Out:
# {'Content-Type': 'application/json',
#  'Ocp-Apim-Subscription-Key': 'e8e591d41a0b43bf8f21da161c204ad2'}

# %% [markdown]
# # -------------------------Python Form Recognizer Async Analyze-----------------------

# %%
########### Python Form Recognizer Async Analyze #############
import json
import time
from requests import get, post

model_id='62a96766-80f6-4c23-867b-af07a527d9da'


# Endpoint URL
endpoint = r"https://checklistformreader.cognitiveservices.azure.com"
apim_key = "e8e591d41a0b43bf8f21da161c204ad2"
#model_id = "2e4ce549-aa24-4699-a334-f889ef74b1ae"
post_url = endpoint + "/formrecognizer/v2.0/custom/models/%s/analyze" % model_id
#source = r"https://checklistform.blob.core.windows.net/forms?sv=2019-10-10&ss=bfqt&srt=sco&sp=rwdlacupx&se=2020-07-03T12:14:27Z&st=2020-07-02T04:14:27Z&spr=https&sig=3vfhXmNcmVfZltWhXTDWl6q58fa%2FW1s1kPNiJlaRnb4%3D"

source = r"C:\Users\ashishkumd2\Desktop\PowerApps\AleSodte_Workspace.pdf"
params = {
    "includeTextDetails": True
}
headers = {
    # Request headers
    'Content-Type': 'application/pdf',
        'Ocp-Apim-Subscription-Key': apim_key,
}

with open(source, "rb") as f:
    data_bytes = f.read()
#print(data_bytes)
try:
    resp = post(url = post_url, data = data_bytes, headers = headers, params = params)
    if resp.status_code != 202:
        print("POST analyze failed:\n%s" % resp.json())
        #quit()
    print("POST analyze succeeded:\n%s" % resp.headers)
    get_url = resp.headers["operation-location"]
except Exception as e:
    print("POST analyze failed:\n%s" % str(e))
    #quit()
# Out:
# POST analyze succeeded:
# {'Content-Length': '0', 'Operation-Location': 'https://checklistformreader.cognitiveservices.azure.com/formrecognizer/v2.0/custom/models/62a96766-80f6-4c23-867b-af07a527d9da/analyzeresults/174c922d-2627-4323-be61-5912f80cbb0a', 'x-envoy-upstream-service-time': '5445', 'apim-request-id': '1516e3d7-42aa-476a-901e-3df58a2cce7e', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'Date': 'Fri, 14 Aug 2020 04:43:05 GMT'}

# %%
n_tries = 1
n_try = 0
wait_sec = 5
max_wait_sec = 60
while n_try < n_tries:
    try:
        resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
        resp_json = resp.json()
        if resp.status_code != 200:
            print("GET analyze results failed:\n%s" % json.dumps(resp_json))
            quit()
        status = resp_json["status"]
        if status == "succeeded":
            print("Analysis succeeded:\n%s" % json.dumps(resp_json))
            quit()
        if status == "failed":
            print("Analysis failed:\n%s" % json.dumps(resp_json))
            quit()
        # Analysis still running. Wait and retry.
        time.sleep(wait_sec)
        n_try += 1
        wait_sec = min(2*wait_sec, max_wait_sec)     
    except Exception as e:
        msg = "GET analyze results failed:\n%s" % str(e)
        print(msg)
        quit()
print("Analyze operation did not complete within the allocated time.")
# Out:
# Analysis succeeded:
# ...

# %%
########### Python Form Recognizer Async Analyze #############
import json
import time
import getopt
import sys
import os
from requests import get, post

def main(argv):
    input_file, output_file, file_type = getArguments(argv)
    runAnalysis(input_file, output_file, file_type)

def runAnalysis(input_file, output_file, file_type):
    # Endpoint URL
    endpoint = r"https://checklistformreader.cognitiveservices.azure.com/"
    # Subscription Key
    apim_key = "e8e591d41a0b43bf8f21da161c204ad2"
    # Model ID
    model_id = "d3911f0f-0e8d-45a4-8b0c-dab3f122f448"
    post_url = endpoint + "/formrecognizer/v2.0-preview/custom/models/%s/analyze" % model_id
    params = {
        "includeTextDetails": True
    }

    headers = {
        # Request headers
        'Content-Type': file_type,
        'Ocp-Apim-Subscription-Key': apim_key,
    }
    try:
        with open(input_file, "rb") as f:
            data_bytes = f.read()
    except IOError:
        print("Inputfile not accessible.")
        sys.exit(2)

    try:
        print('Initiating analysis...')
        resp = post(url = post_url, data = data_bytes, headers = headers, params = params)
        if resp.status_code != 202:
            print("POST analyze failed:\n%s" % json.dumps(resp.json()))
            quit()
        print("POST analyze succeeded:\n%s" % resp.headers)
        print
        get_url = resp.headers["operation-location"]
    except Exception as e:
        print("POST analyze failed:\n%s" % str(e))
        quit()

    n_tries = 15
    n_try = 0
    wait_sec = 5
    max_wait_sec = 60
    print()
    print('Getting analysis results...')
    while n_try < n_tries:
        try:
            resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
            resp_json = resp.json()
            if resp.status_code != 200:
                print("GET analyze results failed:\n%s" % json.dumps(resp_json))
                quit()
            status = resp_json["status"]
            if status == "succeeded":
                if output_file:
                    with open(output_file, 'w') as outfile:
                        json.dump(resp_json, outfile, indent=2, sort_keys=True)
                print("Analysis succeeded:\n%s" % json.dumps(resp_json, indent=2, sort_keys=True))
                quit()
            if status == "failed":
                print("Analysis failed:\n%s" % json.dumps(resp_json))
                quit()
            # Analysis still running. Wait and retry.
            time.sleep(wait_sec)
            n_try += 1
            wait_sec = min(2*wait_sec, max_wait_sec)     
        except Exception as e:
            msg = "GET analyze results failed:\n%s" % str(e)
            print(msg)
            quit()
    print("Analyze operation did not complete within the allocated time.")

def getArguments(argv):
    input_file = ''
    file_type = ''
    output_file = ''
    try:
        opts, args = getopt.gnu_getopt(argv, "ht:o:", [])
    except getopt.GetoptError:
        printCommandDescription(2)

    for opt, arg in opts:
        if opt == '-h':
            printCommandDescription()

    if len(args) != 1:
        printCommandDescription()
    else:
        input_file = args[0]
    
    for opt, arg in opts:
        if opt == '-t':
            if arg not in ('application/pdf', 'image/jpeg', 'image/png', 'image/tiff'):
                print('Type ' + file_type + ' not supported')
                sys.exit()
            else:
                file_type = arg
        
        if opt == '-o':
            output_file = arg
            try:
                open(output_file, 'a')
            except IOError:
                print("Output file not creatable")
                sys.exit(2)

    if not file_type:   
        file_type = inferrType(input_file)

    return (input_file, output_file, file_type)

def inferrType(input_file):
    filename, file_extension = os.path.splitext(input_file)
    if file_extension ==  '': 
        print('File extension could not be inferred from inputfile. Provide type as an argument.')
        sys.exit()    
    elif file_extension == '.pdf':
        return 'application/pdf'
    elif file_extension ==  '.jpeg':
        return 'image/jpeg'
    elif file_extension ==  '.png':
        return 'image/png'
    elif file_extension ==  '.tiff':
        return 'image/tiff'
    else:
        print('File extension ' + file_extension + ' not supported')
        sys.exit()

def printCommandDescription(exit_status=0):
    print('analyze.py <inputfile> [-t <type>] [-o <outputfile>]')
    print
    print('If type option is not provided, type will be inferred from file extension.')
    sys.exit(exit_status)

if __name__ == '__main__':
    main(sys.argv[1:])
    print(sys.argv[1:])
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# analyze.py <inputfile> [-t <type>] [-o <outputfile>]
# If type option is not provided, type will be inferred from file extension.
# Traceback (most recent call last):
#   File "<ipython-input-2-92055885e6b2>", line 88, in getArguments
#     opts, args = getopt.gnu_getopt(argv, "ht:o:", [])
#   File "C:\Users\Ashish\anaconda3\lib\getopt.py", line 138, in gnu_getopt
#     opts, args = do_shorts(opts, args[0][1:], shortopts, args[1:])
#   File "C:\Users\Ashish\anaconda3\lib\getopt.py", line 195, in do_shorts
#     if short_has_arg(opt, shortopts):
#   File "C:\Users\Ashish\anaconda3\lib\getopt.py", line 211, in short_has_arg
#     raise GetoptError(_('option -%s not recognized') % opt, opt)
# getopt.GetoptError: option -f not recognized
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
